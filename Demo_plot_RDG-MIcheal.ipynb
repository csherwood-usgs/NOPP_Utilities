# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Water-level data from Florida panhandle during Michael from USGS
#
# This notebook demos reading in the tab-delimited water-level data from four files using Pandas.
#
# All data were downloaded using the Flood Event Viewr to open the legacy web page on 1/20/2023.
#
# Tide guage and wave data
# USGS 301116085443000 ST ANDREWS BAY NEAR PANAMA CITY, FL
# USGS 302341086305600 EAST PASS TO CHOCTAWHATCHEE BAY AT DESTIN FL

# %%
data_dir = r'/vortexfs1/home/csherwood/proj/NOPP_Michael/data/'
sa = 'USGS_301116085443000_ST_ANDREWS_BAY_NEAR_PANAMA_CITY_FL'
ep = 'USGS_302341086305600_EAST_PASS_TO_CHOCTAWHATCHEE_BAY_AT_DESTIN_FL'

# %%
col_names = ['Agency','Site','Date','Time','TZ','Elev ft','Approved'] 
df_sa = pd.read_csv( data_dir + sa + '.txt', skiprows = 28, header=None, names = col_names, delim_whitespace=True )
df_sa['dt'] = pd.to_datetime( df_sa['Date'].astype(str) + ' ' + df_sa['Time'].astype(str) + ' +0500' )
df_sa['Elev (m)'] = df_sa['Elev ft'].values*.3048
df_sa
# Out:
#      Agency             Site        Date   Time   TZ  Elev ft Approved  \
# 0      USGS  301116085443000  2018-10-08  09:10  CDT     1.87        A
# 1      USGS  301116085443000  2018-10-08  09:15  CDT     1.88        A
# 2      USGS  301116085443000  2018-10-08  09:20  CDT     1.88        A
# 3      USGS  301116085443000  2018-10-08  09:25  CDT     1.89        A
# 4      USGS  301116085443000  2018-10-08  09:30  CDT     1.89        A
# ...     ...              ...         ...    ...  ...      ...      ...
# 1900   USGS  301116085443000  2018-10-14  23:35  CDT     1.70        A
# 1901   USGS  301116085443000  2018-10-14  23:40  CDT     1.70        A
# 1902   USGS  301116085443000  2018-10-14  23:45  CDT     1.71        A
# 1903   USGS  301116085443000  2018-10-14  23:50  CDT     1.72        A
# 1904   USGS  301116085443000  2018-10-14  23:55  CDT     1.74        A
#
#                             dt  Elev (m)
# 0    2018-10-08 09:10:00+05:00  0.569976
# 1    2018-10-08 09:15:00+05:00  0.573024
# 2    2018-10-08 09:20:00+05:00  0.573024
# 3    2018-10-08 09:25:00+05:00  0.576072
# 4    2018-10-08 09:30:00+05:00  0.576072
# ...                        ...       ...
# 1900 2018-10-14 23:35:00+05:00  0.518160
# 1901 2018-10-14 23:40:00+05:00  0.518160
# 1902 2018-10-14 23:45:00+05:00  0.521208
# 1903 2018-10-14 23:50:00+05:00  0.524256
# 1904 2018-10-14 23:55:00+05:00  0.530352
#
# [1905 rows x 9 columns]

# %%
col_names = ['Agency','Site No','Date','Time','TZ','Elev ft','Approved'] 
df_ep = pd.read_csv( data_dir + ep + '.txt', skiprows = 29, header=None, names = col_names, delim_whitespace=True )
df_ep['dt'] = pd.to_datetime( df_ep['Date'].astype(str) + ' ' + df_ep['Time'].astype(str) + ' +0500' )
df_ep['Elev (m)'] = df_ep['Elev ft'].values*.3048
df_ep
# Out:
#      Agency          Site No        Date   Time   TZ  Elev ft Approved  \
# 0      USGS  302341086305600  2018-10-08  13:35  CDT     2.32        A
# 1      USGS  302341086305600  2018-10-08  13:40  CDT     2.30        A
# 2      USGS  302341086305600  2018-10-08  13:45  CDT     2.31        A
# 3      USGS  302341086305600  2018-10-08  13:50  CDT     2.32        A
# 4      USGS  302341086305600  2018-10-08  13:55  CDT     2.30        A
# ...     ...              ...         ...    ...  ...      ...      ...
# 1739   USGS  302341086305600  2018-10-14  14:30  CDT     1.33        A
# 1740   USGS  302341086305600  2018-10-14  14:35  CDT     1.35        A
# 1741   USGS  302341086305600  2018-10-14  14:40  CDT     1.35        A
# 1742   USGS  302341086305600  2018-10-14  14:45  CDT     1.34        A
# 1743   USGS  302341086305600  2018-10-14  14:50  CDT     1.35        A
#
#                             dt  Elev (m)
# 0    2018-10-08 13:35:00+05:00  0.707136
# 1    2018-10-08 13:40:00+05:00  0.701040
# 2    2018-10-08 13:45:00+05:00  0.704088
# 3    2018-10-08 13:50:00+05:00  0.707136
# 4    2018-10-08 13:55:00+05:00  0.701040
# ...                        ...       ...
# 1739 2018-10-14 14:30:00+05:00  0.405384
# 1740 2018-10-14 14:35:00+05:00  0.411480
# 1741 2018-10-14 14:40:00+05:00  0.411480
# 1742 2018-10-14 14:45:00+05:00  0.408432
# 1743 2018-10-14 14:50:00+05:00  0.411480
#
# [1744 rows x 9 columns]

# %%
#### Plot all of the water-level data

# %%
plt.plot(df_sa['dt'],df_sa['Elev (m)'], label='St Andrews Bay')
plt.plot(df_ep['dt'],df_ep['Elev (m)'], label='East Pass')

plt.legend()
plt.ylabel('Elevation (m NAVD88)')
_ = plt.xticks(rotation=45)
